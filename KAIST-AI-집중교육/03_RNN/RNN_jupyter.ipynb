# %%
from __future__ import absolute_import, division, print_function

# %%
import numpy as np
import os
import shutil
import tensorflow as tf
#import models
import matplotlib.pylab as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-13f37bb60b43> in <module>
#       2 import os
#       3 import shutil
# ----> 4 import tensorflow as tf
#       5 #import models
#       6 import matplotlib.pylab as plt
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
### load data and split it to training and test data###
data = np.loadtxt('stock_data.txt')
data_train_X = data[:450,:]
data_train_Y = data[1:451,:]
data_test_X  = data[450:-1,:]
data_test_Y  = data[451:,:]

#print(data_train_X);
#print(data_train_Y);

# %%
### Hyperparameters ### 
INPUT_SIZE    = 9
OUTPUT_SIZE   = 9
HIDDEN_SIZE   = 100
LEARNING_RATE = 0.005
nEpoch 	      = 500

# %%
### Grapch ### 
# placehoders for inputs and outputs
inputs   = tf.placeholder(tf.float32, (None, INPUT_SIZE))  
outputs  = tf.placeholder(tf.float32, (None, OUTPUT_SIZE)) 
inputs_  = tf.expand_dims(inputs,0)
outputs_ = tf.expand_dims(outputs,0)

print(inputs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-06ac6035ba8b> in <module>
#       1 ### Grapch ###
#       2 # placehoders for inputs and outputs
# ----> 3 inputs   = tf.placeholder(tf.float32, (None, INPUT_SIZE))
#       4 outputs  = tf.placeholder(tf.float32, (None, OUTPUT_SIZE))
#       5 inputs_  = tf.expand_dims(inputs,0)
#
# NameError: name 'tf' is not defined

# %%
# RNN/LSTM layer
#cell = tf.nn.rnn_cell.BasicRNNCell(HIDDEN_SIZE)
#cell = tf.nn.rnn_cell.BasicLSTMCell(HIDDEN_SIZE)
cell = tf.nn.rnn_cell.GRUCell(HIDDEN_SIZE)
#cell = models.BasicRNNCell(HIDDEN_SIZE)
#cell = models.BasicLSTMCell(HIDDEN_SIZE)
#cell = models.GRUCell(HIDDEN_SIZE)
#print(cell)

rnn_outputs, rnn_states = tf.nn.dynamic_rnn(cell, inputs_, dtype=tf.float32)
#print(rnn_outputs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-6e94298d808a> in <module>
#       8 #print(cell)
#       9
# ---> 10 rnn_outputs, rnn_states = tf.nn.dynamic_rnn(cell, inputs_, dtype=tf.float32)
#      11 #print(rnn_outputs)
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\util\deprecation.py in new_func(*args, **kwargs)
#     322               'in a future version' if date is None else ('after %s' % date),
#     323               instructions)
# --> 324       return func(*args, **kwargs)
#     325     return tf_decorator.make_decorator(
#     326         func, new_func, 'deprecated',
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\rnn.py in dynamic_rnn(cell, inputs, sequence_length, initial_state, dtype, parallel_iterations, swap_memory, time_major, scope)
#     669         swap_memory=swap_memory,
#     670         sequence_length=sequence_length,
# --> 671         dtype=dtype)
#     672
#     673     # Outputs of _dynamic_rnn_loop are always shaped [time, batch, depth].
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\rnn.py in _dynamic_rnn_loop(cell, inputs, initial_state, parallel_iterations, swap_memory, sequence_length, dtype)
#     877       parallel_iterations=parallel_iterations,
#     878       maximum_iterations=time_steps,
# --> 879       swap_memory=swap_memory)
#     880
#     881   # Unpack final output if not using output tuples.
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\control_flow_ops.py in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#    3554       ops.add_to_collection(ops.GraphKeys.WHILE_CONTEXT, loop_context)
#    3555     result = loop_context.BuildLoop(cond, body, loop_vars, shape_invariants,
# -> 3556                                     return_same_structure)
#    3557     if maximum_iterations is not None:
#    3558       return result[1]
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\control_flow_ops.py in BuildLoop(self, pred, body, loop_vars, shape_invariants, return_same_structure)
#    3085       with ops.get_default_graph()._mutation_lock():  # pylint: disable=protected-access
#    3086         original_body_result, exit_vars = self._BuildLoop(
# -> 3087             pred, body, original_loop_vars, loop_vars, shape_invariants)
#    3088     finally:
#    3089       self.Exit()
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\control_flow_ops.py in _BuildLoop(self, pred, body, original_loop_vars, loop_vars, shape_invariants)
#    3020         flat_sequence=vars_for_body_with_tensor_arrays)
#    3021     pre_summaries = ops.get_collection(ops.GraphKeys._SUMMARY_COLLECTION)  # pylint: disable=protected-access
# -> 3022     body_result = body(*packed_vars_for_body)
#    3023     post_summaries = ops.get_collection(ops.GraphKeys._SUMMARY_COLLECTION)  # pylint: disable=protected-access
#    3024     if not nest.is_sequence(body_result):
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\control_flow_ops.py in <lambda>(i, lv)
#    3523         cond = lambda i, lv: (  # pylint: disable=g-long-lambda
#    3524             math_ops.logical_and(i < maximum_iterations, orig_cond(*lv)))
# -> 3525         body = lambda i, lv: (i + 1, orig_body(*lv))
#    3526
#    3527     if context.executing_eagerly():
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\rnn.py in _time_step(time, output_ta_t, state)
#     845           skip_conditionals=True)
#     846     else:
# --> 847       (output, new_state) = call_cell()
#     848
#     849     # Keras cells always wrap state as list, even if it's a single tensor.
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\rnn.py in <lambda>()
#     831     if is_keras_rnn_cell and not nest.is_sequence(state):
#     832       state = [state]
# --> 833     call_cell = lambda: cell(input_t, state)
#     834
#     835     if sequence_length is not None:
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\rnn_cell_impl.py in __call__(self, inputs, state, scope, *args, **kwargs)
#     369     # method.  See the class docstring for more details.
#     370     return base_layer.Layer.__call__(self, inputs, state, scope=scope,
# --> 371                                      *args, **kwargs)
#     372
#     373
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\layers\base.py in __call__(self, inputs, *args, **kwargs)
#     528
#     529       # Actually call layer
# --> 530       outputs = super(Layer, self).__call__(inputs, *args, **kwargs)
#     531
#     532     if not context.executing_eagerly():
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, inputs, *args, **kwargs)
#     536       if not self.built:
#     537         # Build layer if applicable (if the `build` method has been overridden).
# --> 538         self._maybe_build(inputs)
#     539         # We must set self.built since user defined build functions are not
#     540         # constrained to set self.built.
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in _maybe_build(self, inputs)
#    1601     # Only call `build` if the user has manually overridden the build method.
#    1602     if not hasattr(self.build, '_is_default'):
# -> 1603       self.build(input_shapes)
#    1604
#    1605   def __setattr__(self, name, value):
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\keras\utils\tf_utils.py in wrapper(instance, input_shape)
#     149       else:
#     150         input_shape = tuple(tensor_shape.TensorShape(input_shape).as_list())
# --> 151     output_shape = fn(instance, input_shape)
#     152     if output_shape is not None:
#     153       if isinstance(output_shape, list):
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\rnn_cell_impl.py in build(self, inputs_shape)
#     537         "gates/%s" % _WEIGHTS_VARIABLE_NAME,
#     538         shape=[input_depth + self._num_units, 2 * self._num_units],
# --> 539         initializer=self._kernel_initializer)
#     540     self._gate_bias = self.add_variable(
#     541         "gates/%s" % _BIAS_VARIABLE_NAME,
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in add_variable(self, *args, **kwargs)
#    1230   def add_variable(self, *args, **kwargs):
#    1231     """Alias for `add_weight`."""
# -> 1232     return self.add_weight(*args, **kwargs)
#    1233
#    1234   @property
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\layers\base.py in add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint, use_resource, synchronization, aggregation, partitioner)
#     433             synchronization=synchronization,
#     434             aggregation=aggregation,
# --> 435             getter=vs.get_variable)
#     436
#     437         if regularizer:
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint, partitioner, use_resource, synchronization, aggregation, **kwargs)
#     347         collections=collections,
#     348         synchronization=synchronization,
# --> 349         aggregation=aggregation)
#     350     backend.track_variable(variable)
#     351
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\training\checkpointable\base.py in _add_variable_with_custom_getter(self, name, shape, dtype, initializer, getter, overwrite, **kwargs_for_getter)
#     605     new_variable = getter(
#     606         name=name, shape=shape, dtype=dtype, initializer=initializer,
# --> 607         **kwargs_for_getter)
#     608
#     609     # If we set an initializer and the variable processed it, tracking will not
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\variable_scope.py in get_variable(name, shape, dtype, initializer, regularizer, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint, synchronization, aggregation)
#    1477       constraint=constraint,
#    1478       synchronization=synchronization,
# -> 1479       aggregation=aggregation)
#    1480
#    1481
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\variable_scope.py in get_variable(self, var_store, name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint, synchronization, aggregation)
#    1218           constraint=constraint,
#    1219           synchronization=synchronization,
# -> 1220           aggregation=aggregation)
#    1221
#    1222   def _get_partitioned_variable(self,
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\variable_scope.py in get_variable(self, name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint, synchronization, aggregation)
#     545           constraint=constraint,
#     546           synchronization=synchronization,
# --> 547           aggregation=aggregation)
#     548
#     549   def _get_partitioned_variable(self,
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\variable_scope.py in _true_getter(name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, constraint, synchronization, aggregation)
#     497           constraint=constraint,
#     498           synchronization=synchronization,
# --> 499           aggregation=aggregation)
#     500
#     501     # Set trainable value based on synchronization value.
#
# C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\variable_scope.py in _get_single_variable(self, name, shape, dtype, initializer, regularizer, partition_info, reuse, trainable, collections, caching_device, validate_shape, use_resource, constraint, synchronization, aggregation)
#     846         tb = [x for x in tb if "tensorflow/python" not in x[0]][:3]
#     847         raise ValueError("%s Originally defined at:\n\n%s" % (err_msg, "".join(
# --> 848             traceback.format_list(tb))))
#     849       found_var = self._vars[name]
#     850       if not shape.is_compatible_with(found_var.get_shape()):
#
# ValueError: Variable rnn/gru_cell/gates/kernel already exists, disallowed. Did you mean to set reuse=True or reuse=tf.AUTO_REUSE in VarScope? Originally defined at:
#
#   File "C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\ops.py", line 1801, in __init__
#     self._traceback = tf_stack.extract_stack()
#   File "C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\ops.py", line 3300, in create_op
#     op_def=op_def)
#   File "C:\ProgramData\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\util\deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)

# %%
# Output layer 
pred = tf.layers.dense(rnn_outputs, OUTPUT_SIZE)

# objective function 
mse = tf.reduce_mean(tf.square(pred - outputs_))

tf.summary.scalar("loss", mse)
merge_op = tf.summary.merge_all()

#optimizer = tf.train.AdamOptimizer(learning_rate=0.01)
optimizer = tf.train.AdamOptimizer(LEARNING_RATE)
minimize = optimizer.minimize(mse)
# Out:
# WARNING:tensorflow:From <ipython-input-20-d0a974644352>:3: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.

# %%
### run ### 
sess = tf.Session()
sess.run(tf.global_variables_initializer())

if os.path.exists('train'):
  shutil.rmtree('train')
if os.path.exists('val'):
  shutil.rmtree('val')
os.mkdir('train')
os.mkdir('val')
train_writer = tf.summary.FileWriter('train', sess.graph)
val_writer = tf.summary.FileWriter('val', sess.graph)

for i in range(nEpoch):
  _, train_mse, summary = sess.run([minimize, mse, merge_op], {inputs: data_train_X, outputs: data_train_Y})
  train_writer.add_summary(summary, i)
  test_mse, summary = sess.run([mse, merge_op], {inputs: data_test_X, outputs: data_test_Y})
  val_writer.add_summary(summary, i)
  print("Epoch: %d Train MSE: %.5f Test MSE: %.5f " % (i+1, train_mse, test_mse))

pred_train = sess.run(pred, {inputs:data_train_X, outputs:data_train_Y})
pred_test = sess.run(pred, {inputs:data_test_X, outputs:data_test_Y})
# Out:
# Epoch: 1 Train MSE: 0.00025 Test MSE: 0.00179
# Epoch: 2 Train MSE: 0.00203 Test MSE: 0.00033
# Epoch: 3 Train MSE: 0.00047 Test MSE: 0.00023
# Epoch: 4 Train MSE: 0.00038 Test MSE: 0.00025
# Epoch: 5 Train MSE: 0.00042 Test MSE: 0.00021
# Epoch: 6 Train MSE: 0.00037 Test MSE: 0.00016
# Epoch: 7 Train MSE: 0.00030 Test MSE: 0.00016
# Epoch: 8 Train MSE: 0.00029 Test MSE: 0.00020
# Epoch: 9 Train MSE: 0.00031 Test MSE: 0.00022
# Epoch: 10 Train MSE: 0.00032 Test MSE: 0.00019
# Epoch: 11 Train MSE: 0.00028 Test MSE: 0.00015
# Epoch: 12 Train MSE: 0.00026 Test MSE: 0.00014
# Epoch: 13 Train MSE: 0.00026 Test MSE: 0.00014
# Epoch: 14 Train MSE: 0.00027 Test MSE: 0.00014
# Epoch: 15 Train MSE: 0.00028 Test MSE: 0.00013
# Epoch: 16 Train MSE: 0.00027 Test MSE: 0.00012
# Epoch: 17 Train MSE: 0.00025 Test MSE: 0.00012
# Epoch: 18 Train MSE: 0.00024 Test MSE: 0.00013
# Epoch: 19 Train MSE: 0.00024 Test MSE: 0.00015
# Epoch: 20 Train MSE: 0.00025 Test MSE: 0.00016
# Epoch: 21 Train MSE: 0.00025 Test MSE: 0.00015
# Epoch: 22 Train MSE: 0.00025 Test MSE: 0.00014
# Epoch: 23 Train MSE: 0.00024 Test MSE: 0.00012
# Epoch: 24 Train MSE: 0.00023 Test MSE: 0.00012
# Epoch: 25 Train MSE: 0.00023 Test MSE: 0.00012
# Epoch: 26 Train MSE: 0.00023 Test MSE: 0.00012
# Epoch: 27 Train MSE: 0.00024 Test MSE: 0.00012
